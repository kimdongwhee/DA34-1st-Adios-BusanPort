# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('data/관세청_전국 및 부산권항 선용품 무역통계_20240131.xlsx',sheet_name='2018년',
                 header=[5,6],index_col=0)

# %%
df
# Out:
# 항구/선박 구분                   거래구분          품목\n(대분류) 2018.1.           2018.2.  \
#              Unnamed: 1_level_1 Unnamed: 2_level_1      건수        금액      건수
# 전국 (크루즈선 포함)              외국선용품                 합계   86554  46374466   73928
# NaN                         NaN                 주류    9330   2712227    7685
# NaN                         NaN                담배류    6698   1555854    5502
# NaN                         NaN                육류     9844   1285790    8637
# NaN                         NaN                식품류   44679   2050939   38485
# ...                         ...                ...     ...       ...     ...
# NaN                         NaN                 유류     NaN       NaN     NaN
# NaN                         NaN             조건부선용품     NaN       NaN     NaN
# NaN                         NaN              선박폐기물     NaN       NaN     NaN
# NaN                         NaN                 기타     NaN       NaN       1
# ...
